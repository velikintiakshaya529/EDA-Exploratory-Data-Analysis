# %% [markdown]
# ## PART 1 — PROJECT INTRODUCTION
# ### Step 1.1 — Project Title

# %% [markdown]
# ## Bank Marketing Campaign Analysis – Exploratory Data Analysis

# %% [markdown]
# ## Step 1.2 — Introduction
#
# ### 1. Introduction
#
# Bank marketing campaigns involve contacting customers to promote financial products such as term deposits. Understanding customer characteristics, campaign interactions, and previous contact information can help identify patterns in customer responses.
#
# This project performs Exploratory Data Analysis (EDA) on a Bank Marketing dataset to understand customer profiles, campaign characteristics, and factors associated with term deposit subscription.

# %% [markdown]
# ## Step 1.3 — Project Objective
#
# ### 2. Objective of the Project
#
# The main objectives of this project are:
#
# - To understand the structure and characteristics of the Bank Marketing dataset.
# - To clean and prepare the dataset for analysis.
# - To analyze customer demographic characteristics.
# - To study campaign-related variables and customer interactions.
# - To identify patterns associated with term deposit subscription.
# - To perform univariate, bivariate, and multivariate analysis.
# - To create pivot tables for additional analysis.
# - To derive meaningful insights from the data.

# %% [markdown]
# ## PART 2 — DATASET INFORMATION

# %% [markdown]
# ## Step 2.1 — Dataset Information
# ### 3. Dataset Information
#
# The dataset used for this project contains information about customers contacted during a bank marketing campaign.
#
# ### Dataset Dimensions
#
# - Number of records: 41,188
# - Number of columns: 21
# - Target variable: `y`
# - Target categories: `yes` and `no`
#
# The target variable `y` indicates whether the customer subscribed to the bank's term deposit.

# %% [markdown]
# ## PART 3 — IMPORT LIBRARIES

# %% [markdown]
# ### 4. Import Required Libraries
#
# The following Python libraries are used for data manipulation, statistical analysis, and visualization.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## PART 4 — LOAD DATASET
# ### 5. Load Dataset
#
# The Bank Marketing dataset is loaded into a pandas DataFrame for analysis.

# %%
import pandas as pd

df = pd.read_csv("bank-full.csv", sep=";")

df
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %% [markdown]
# ## PART 5 — DATA OBSERVATION

# %%
# Display first 5 rows

df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp_var_rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
# Check the shape

print("Number of Rows:", df.shape[0])
print("Number of Columns:", df.shape[1])
# Out:
# Number of Rows: 41188
# Number of Columns: 21

# %%
# Check column names

df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp_var_rate', 'cons_price_idx',
#        'cons_conf_idx', 'euribor3m', 'nr_employed', 'y'],
#       dtype='object')

# %%
# Check data types and non-null values

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp_var_rate    41188 non-null  float64
#  16  cons_price_idx  41188 non-null  float64
# ...

# %%
# Check numerical summary

df.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp_var_rate  cons_price_idx  cons_conf_idx     euribor3m   nr_employed
# count  41188.000000    41188.000000   41188.000000  41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291   5167.035911
# ...

# %%
# Check categorical summary

df.describe(include="object")
# Out:
#            job  marital          education default housing   loan   contact  \
# count    41188    41188              41188   41188   41188  41188     41188
# unique      12        4                  8       3       3      3         2
# top     admin.  married  university.degree      no     yes     no  cellular
# freq     10422    24928              12168   32588   21576  33950     26144
#
#         month day_of_week     poutcome      y
# count   41188       41188        41188  41188
# unique     10           5            3      2
# top       may         thu  nonexistent     no
# freq    13769        8623        35563  36548

# %%
df.columns = (
    df.columns
    .str.strip()
    .str.lower()
    .str.replace(".", "_", regex=False)
)

df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp_var_rate', 'cons_price_idx',
#        'cons_conf_idx', 'euribor3m', 'nr_employed', 'y'],
#       dtype='object')

# %% [markdown]
# ## PART 6 — DATA CLEANING & PREPARATION
# ### Missing Values

# %%
df.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp_var_rate      0
# cons_price_idx    0
# cons_conf_idx     0
# euribor3m         0
# nr_employed       0
# y                 0
# dtype: int64

# %%
missing_percentage = (df.isnull().sum() / len(df)) * 100
missing_percentage.sort_values(ascending=False)
# Out:
# age               0.0
# job               0.0
# marital           0.0
# education         0.0
# default           0.0
# housing           0.0
# loan              0.0
# contact           0.0
# month             0.0
# day_of_week       0.0
# duration          0.0
# campaign          0.0
# pdays             0.0
# previous          0.0
# poutcome          0.0
# emp_var_rate      0.0
# cons_price_idx    0.0
# cons_conf_idx     0.0
# euribor3m         0.0
# nr_employed       0.0
# y                 0.0
# dtype: float64

# %% [markdown]
# ### Duplicate Records

# %%
print("Number of duplicate rows:", df.duplicated().sum())
# Out:
# Number of duplicate rows: 12

# %%
df = df.drop_duplicates()

# %%
print("Duplicate rows after removal:", df.duplicated().sum())
print("Dataset shape after removing duplicates:", df.shape)
# Out:
# Duplicate rows after removal: 0
# Dataset shape after removing duplicates: (41176, 21)

# %% [markdown]
# ###  Unknown Value Analysis

# %%
for col in df.select_dtypes(include="object").columns:
    unknown_count = (df[col] == "unknown").sum()
    if unknown_count > 0:
        print(col, ":", unknown_count)
# Out:
# job : 330
# marital : 80
# education : 1731
# default : 8597
# housing : 990
# loan : 990

# %%
df
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %% [markdown]
# ### Outlier Detection

# %%
numeric_cols = df.select_dtypes(include="number").columns

print("Numerical columns:")
print(numeric_cols)
# Out:
# Numerical columns:
# Index(['age', 'duration', 'campaign', 'pdays', 'previous', 'emp_var_rate',
#        'cons_price_idx', 'cons_conf_idx', 'euribor3m', 'nr_employed'],
#       dtype='object')

# %%
df[numeric_cols].describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41176.00000  41176.000000  41176.000000  41176.000000  41176.000000
# mean      40.02380    258.315815      2.567879    962.464810      0.173013
# std       10.42068    259.305321      2.770318    186.937102      0.494964
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp_var_rate  cons_price_idx  cons_conf_idx     euribor3m   nr_employed
# count  41176.000000    41176.000000   41176.000000  41176.000000  41176.000000
# mean       0.081922       93.575720     -40.502863      3.621293   5167.034870
# ...

# %%
numeric_cols = df.select_dtypes(include="number").columns

Q1 = df[numeric_cols].quantile(0.25)
Q3 = df[numeric_cols].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outlier_count = (
    (df[numeric_cols] < lower_bound) |
    (df[numeric_cols] > upper_bound)
).sum()

print("Outlier count by column:")
print(outlier_count.sort_values(ascending=False))
# Out:
# Outlier count by column:
# previous          5625
# duration          2963
# campaign          2406
# pdays             1515
# age                468
# cons_conf_idx      446
# emp_var_rate         0
# cons_price_idx       0
# euribor3m            0
# nr_employed          0
# dtype: int64

# %% [markdown]
# ### Class Imbalance

# %%
print(df["y"].value_counts())
# Out:
# y
# no     36537
# yes     4639
# Name: count, dtype: int64

# %%
print(df["y"].value_counts(normalize=True) * 100)
# Out:
# y
# no     88.733728
# yes    11.266272
# Name: proportion, dtype: float64

# %% [markdown]
# ## PART 7 - Exploratory Data Analysis

# %% [markdown]
# ### Step 1: Univariate Analysis — Target Variable
# ## Exploratory Data Analysis
#
# ### Univariate Analysis
#
# Univariate analysis is used to examine the distribution of individual variables and understand the characteristics of the dataset.
#
# ### Target Variable Distribution
#
# The target variable `y` indicates whether the customer subscribed to the term deposit.

# %%
plt.figure(figsize=(6, 4))

sns.countplot(data=df, x="y")

plt.title("Term Deposit Subscription Distribution")
plt.xlabel("Subscription")
plt.ylabel("Number of Customers")

plt.show()

# %% [markdown]
# ### Interpretation
#
# The target variable shows that the majority of customers did not subscribe to the term deposit, while a smaller proportion of customers subscribed. This indicates that the target variable is imbalanced, with the `no` class representing the majority of observations.

# %% [markdown]
# ### Step 2: Univariate Analysis — Age Distribution

# %% [markdown]
# ### Age Distribution
#
# Age is a numerical variable that represents the age of customers in the dataset.
# A histogram is used to understand the distribution of customer ages and identify the age ranges that occur most frequently.

# %%
plt.figure(figsize=(8, 5))

sns.histplot(data=df, x="age", bins=20, kde=True)

plt.title("Distribution of Customer Age")
plt.xlabel("Age")
plt.ylabel("Number of Customers")

plt.show()

# %% [markdown]
# ### Interpretation
#
# The age distribution shows how customers are spread across different age groups.
# Most customers are concentrated within the common working-age ranges, while relatively fewer observations are found at the extreme younger and older ages.
# The histogram helps identify the central age range and overall spread of customers in the dataset.

# %% [markdown]
# ### Step 3: Univariate Analysis — Job Distribution

# %% [markdown]
# ### Job Distribution
#
# The `job` variable represents the occupation of customers.
# A count plot is used to compare the number of customers across different job categories.

# %%
plt.figure(figsize=(10, 5))

sns.countplot(data=df, x="job", order=df["job"].value_counts().index)

plt.title("Distribution of Customers by Job")
plt.xlabel("Job")
plt.ylabel("Number of Customers")
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ### Interpretation
#
# The job distribution shows that customers belong to different occupational categories.
# Some job categories have considerably more customers than others, indicating that the dataset is not evenly distributed across occupations.
# The `unknown` category represents customers whose job information was unavailable and was retained during data cleaning.

# %% [markdown]
# ### Step 4: Univariate Analysis — Education Distribution

# %%
plt.figure(figsize=(10, 5))

sns.countplot(
    data=df,
    x="education",
    order=df["education"].value_counts().index
)

plt.title("Distribution of Customers by Education")
plt.xlabel("Education")
plt.ylabel("Number of Customers")
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ### Interpretation
#
# The education distribution shows that customers have different levels of educational backgrounds.
# Some education categories contain substantially more customers than others, indicating that the dataset is not evenly distributed across education levels.
# The `unknown` category represents customers whose education information was unavailable and was retained during data cleaning.

# %% [markdown]
# ### Step 5: Univariate Analysis — Marital Status

# %% [markdown]
# ### Marital Status Distribution
#
# The `marital` variable represents the marital status of customers.
# A count plot is used to compare the number of customers across different marital status categories.

# %%
plt.figure(figsize=(8, 5))

sns.countplot(
    data=df,
    x="marital",
    order=df["marital"].value_counts().index
)

plt.title("Distribution of Customers by Marital Status")
plt.xlabel("Marital Status")
plt.ylabel("Number of Customers")

plt.show()

# %% [markdown]
# ### Interpretation
#
# The marital status distribution shows that customers belong to different marital status categories.
# Some categories contain considerably more customers than others, indicating that the dataset is not evenly distributed across marital statuses.
# The `unknown` category represents customers whose marital status information was unavailable and was retained during data cleaning.

# %% [markdown]
# ### Step 6: Univariate Analysis — Housing Loan

# %% [markdown]
# ### Housing Loan Distribution
#
# The `housing` variable indicates whether a customer has a housing loan.
# A count plot is used to compare customers with and without a housing loan.

# %%
plt.figure(figsize=(7, 5))

sns.countplot(
    data=df,
    x="housing",
    order=df["housing"].value_counts().index
)

plt.title("Distribution of Customers by Housing Loan")
plt.xlabel("Housing Loan")
plt.ylabel("Number of Customers")

plt.show()

# %% [markdown]
# ### Interpretation
#
# The distribution shows the number of customers with and without a housing loan.
# The categories are not evenly distributed, indicating that one group contains more customers than the other.
# The `unknown` category represents customers for whom housing loan information was unavailable and was retained during data cleaning.

# %% [markdown]
# ### Step 7: Univariate Analysis — Personal Loan

# %% [markdown]
# ### Personal Loan Distribution
#
# The `loan` variable indicates whether a customer has a personal loan.
# A count plot is used to compare customers with and without a personal loan.

# %%
plt.figure(figsize=(7, 5))

sns.countplot(
    data=df,
    x="loan",
    order=df["loan"].value_counts().index
)

plt.title("Distribution of Customers by Personal Loan")
plt.xlabel("Personal Loan")
plt.ylabel("Number of Customers")

plt.show()

# %% [markdown]
# ### Interpretation
#
# The distribution shows the number of customers with and without a personal loan.
# The categories are not evenly distributed, indicating that one group contains more customers than the other.
# The `unknown` category represents customers for whom personal loan information was unavailable and was retained during data cleaning.

# %% [markdown]
# ### Step 8: Univariate Analysis — Contact Communication Type

# %% [markdown]
# ### Contact Communication Type
#
# The `contact` variable represents the communication method used to contact customers during the marketing campaign.
# A count plot is used to compare the number of customers contacted through each communication method.

# %%
plt.figure(figsize=(7, 5))

sns.countplot(
    data=df,
    x="contact",
    order=df["contact"].value_counts().index
)

plt.title("Distribution of Customers by Contact Type")
plt.xlabel("Contact Type")
plt.ylabel("Number of Customers")

plt.show()

# %% [markdown]
# ### Interpretation
#
# The distribution shows the number of customers contacted through different communication methods.
# The count plot helps compare the frequency of each contact type used during the marketing campaign.

# %% [markdown]
# ### Step 9: Univariate Analysis — Monthly Contact Distribution

# %% [markdown]
# ### Monthly Contact Distribution
#
# The `month` variable represents the month in which customers were contacted during the marketing campaign.
# A count plot is used to compare the number of customer contacts across different months.

# %%
plt.figure(figsize=(8, 5))

sns.countplot(
    data=df,
    x="month",
    order=df["month"].value_counts().index
)

plt.title("Distribution of Customer Contacts by Month")
plt.xlabel("Month")
plt.ylabel("Number of Customers")

plt.show()

# %% [markdown]
# ### Interpretation
#
# The distribution shows that customer contacts were not evenly distributed across all months.
# Some months have substantially more customer contacts than others.
# This indicates that the marketing campaign activity varied across different months.

# %% [markdown]
# ### Step 10: Univariate Analysis — Contact Distribution by Day of Week

# %% [markdown]
# ### Contact Distribution by Day of Week
#
# The `day_of_week` variable represents the day of the week on which customers were contacted during the marketing campaign.
# A count plot is used to compare the number of customer contacts across different days of the week.

# %%
plt.figure(figsize=(8, 5))

sns.countplot(
    data=df,
    x="day_of_week",
    order=df["day_of_week"].value_counts().index
)

plt.title("Distribution of Customer Contacts by Day of Week")
plt.xlabel("Day of Week")
plt.ylabel("Number of Customers")

plt.show()

# %% [markdown]
# ### Interpretation
#
# The distribution shows how customer contacts were spread across different days of the week.
# The number of contacts varies slightly between the days, indicating that campaign activity was not exactly equal on every day.
# The count plot helps identify which days had relatively higher or lower customer contact activity.

# %% [markdown]
# ### Step 11: Univariate Analysis — Call Duration

# %% [markdown]
# ### Call Duration Distribution
#
# The `duration` variable represents the duration of the last contact with a customer, measured in seconds.
# A histogram is used to understand the distribution and spread of call durations.

# %%
plt.figure(figsize=(8, 5))

sns.histplot(data=df, x="duration", bins=30, kde=True)

plt.title("Distribution of Call Duration")
plt.xlabel("Call Duration (seconds)")
plt.ylabel("Number of Customers")

plt.show()

# %% [markdown]
# ### Interpretation
#
# The distribution shows how call durations vary across customers.
# Most calls are concentrated within the lower duration ranges, while a smaller number of calls have much longer durations.
# The distribution is right-skewed, indicating the presence of some relatively long customer interactions.

# %% [markdown]
# ### Step 12: Univariate Analysis — Campaign Contacts

# %% [markdown]
# ### Campaign Contact Distribution
#
# The `campaign` variable represents the number of contacts performed for a customer during the current marketing campaign.
# A histogram is used to understand how frequently customers were contacted during the campaign.

# %%
plt.figure(figsize=(8, 5))

sns.histplot(data=df, x="campaign", bins=30, kde=True)

plt.title("Distribution of Campaign Contacts")
plt.xlabel("Number of Contacts")
plt.ylabel("Number of Customers")

plt.show()

# %% [markdown]
# ### Interpretation
#
# The distribution shows that most customers were contacted a relatively small number of times during the campaign.
# As the number of contacts increases, the number of customers generally decreases.
# A smaller number of customers received many contacts, resulting in a right-skewed distribution.

# %% [markdown]
# ### Step 13: Univariate Analysis — Days Since Previous Contact

# %% [markdown]
# ### Days Since Previous Contact
#
# The `pdays` variable represents the number of days that passed since the customer was previously contacted.
# A histogram is used to understand the distribution of previous contact timing.

# %%
plt.figure(figsize=(8, 5))

sns.histplot(data=df, x="pdays", bins=30, kde=True)

plt.title("Distribution of Days Since Previous Contact")
plt.xlabel("Days Since Previous Contact")
plt.ylabel("Number of Customers")

plt.show()

# %% [markdown]
# ### Interpretation
#
# The distribution of `pdays` is highly concentrated around the value 999.
# In this dataset, `pdays = 999` is a special encoded value indicating that the customer was not previously contacted.
# Therefore, the value 999 should not be treated as a normal numerical outlier.
# Among customers with a previous contact, the remaining values show the number of days since their previous contact.

# %% [markdown]
# ### Step 14: Univariate Analysis — Previous Contacts

# %% [markdown]
# ### Previous Contact Distribution
#
# The `previous` variable represents the number of contacts performed for a customer before the current marketing campaign.
# A histogram is used to understand how frequently customers had been contacted in previous campaigns.

# %%
plt.figure(figsize=(8, 5))

sns.histplot(data=df, x="previous", bins=8, kde=False)

plt.title("Distribution of Previous Contacts")
plt.xlabel("Number of Previous Contacts")
plt.ylabel("Number of Customers")

plt.show()

# %% [markdown]
# ### Interpretation
#
# The distribution shows that most customers had few or no previous contacts before the current marketing campaign.
# The number of customers decreases as the number of previous contacts increases.
# This indicates that repeated contacts from earlier campaigns were less common among customers.

# %% [markdown]
# ### Step 15: Univariate Analysis — Previous Campaign Outcome

# %% [markdown]
# ### Previous Campaign Outcome
#
# The `poutcome` variable represents the outcome of the previous marketing campaign for a customer.
# A count plot is used to compare the number of customers across the different previous campaign outcomes.

# %%
plt.figure(figsize=(8, 5))

sns.countplot(
    data=df,
    x="poutcome",
    order=df["poutcome"].value_counts().index
)

plt.title("Distribution of Previous Campaign Outcomes")
plt.xlabel("Previous Campaign Outcome")
plt.ylabel("Number of Customers")

plt.show()

# %% [markdown]
# ### Interpretation
#
# The distribution shows that previous campaign outcomes are not evenly distributed across customers.
# The `nonexistent` category represents customers for whom there was no previous campaign outcome recorded.
# The `failure` and `success` categories represent customers who had unsuccessful and successful outcomes in previous campaigns.

# %% [markdown]
# ### Step 16: Univariate Analysis — Employment Variation Rate

# %% [markdown]
# ### Employment Variation Rate Distribution
#
# The `emp_var_rate` variable represents the employment variation rate associated with the economic conditions during the marketing campaign.
# A histogram is used to understand its distribution and identify the range of values present in the dataset.

# %%
plt.figure(figsize=(8, 5))

sns.histplot(data=df, x="emp_var_rate", bins=20, kde=True)

plt.title("Distribution of Employment Variation Rate")
plt.xlabel("Employment Variation Rate")
plt.ylabel("Number of Customers")

plt.show()

# %% [markdown]
# ### Interpretation
#
# The distribution shows the range and frequency of employment variation rates recorded during the marketing campaign.
# The values are concentrated around a limited number of economic conditions rather than being evenly distributed across the entire range.
# This variable provides information about the economic environment in which the marketing contacts took place.

# %% [markdown]
# ### Step 17: Univariate Analysis — Consumer Price Index

# %% [markdown]
# ### Consumer Price Index Distribution
#
# The `cons_price_idx` variable represents the consumer price index associated with the economic conditions during the marketing campaign.
# A histogram is used to understand the distribution and range of the values.

# %%
plt.figure(figsize=(8, 5))

sns.histplot(data=df, x="cons_price_idx", bins=20, kde=True)

plt.title("Distribution of Consumer Price Index")
plt.xlabel("Consumer Price Index")
plt.ylabel("Number of Customers")

plt.show()

# %% [markdown]
# ### Interpretation
#
# The distribution shows the range of consumer price index values recorded during the marketing campaign.
# The values are concentrated within a relatively narrow range, indicating that the consumer price index did not vary widely across the observations.
# This variable provides information about the economic conditions during the campaign period.

# %% [markdown]
# ### Step 18: Univariate Analysis — Consumer Confidence Index

# %% [markdown]
# ### Consumer Confidence Index Distribution
#
# The `cons_conf_idx` variable represents the consumer confidence index associated with the economic conditions during the marketing campaign.
# A histogram is used to understand the distribution and range of the values.

# %%
plt.figure(figsize=(8, 5))

sns.histplot(data=df, x="cons_conf_idx", bins=20, kde=True)

plt.title("Distribution of Consumer Confidence Index")
plt.xlabel("Consumer Confidence Index")
plt.ylabel("Number of Customers")

plt.show()

# %% [markdown]
# ### Interpretation
#
# The distribution shows the range of consumer confidence index values recorded during the marketing campaign.
# The values are concentrated within a specific range, indicating that consumer confidence varied within a relatively limited range across the observations.
# This variable provides information about the economic environment during the campaign period.

# %% [markdown]
# ### Step 19: Univariate Analysis — 3-Month Euribor

# %% [markdown]
# ### Month Euribor Distribution
#
# The `euribor3m` variable represents the 3-month Euribor interest rate recorded during the marketing campaign.
# A histogram is used to understand the distribution and range of the values.

# %%
plt.figure(figsize=(8, 5))

sns.histplot(data=df, x="euribor3m", bins=20, kde=True)

plt.title("Distribution of 3-Month Euribor")
plt.xlabel("3-Month Euribor")
plt.ylabel("Number of Customers")

plt.show()

# %% [markdown]
# ### Interpretation
#
# The distribution shows the range of 3-month Euribor values recorded during the marketing campaign.
# The values are concentrated around certain interest-rate levels rather than being evenly distributed across the full range.
# This variable provides information about the interest-rate environment during the campaign period.

# %% [markdown]
# ### Step 20: Univariate Analysis — Number of Employees

# %% [markdown]
# ### Number of Employees Distribution
#
# The `nr_employed` variable represents the number of employees associated with the economic conditions during the marketing campaign.
# A histogram is used to understand the distribution and range of the values.

# %%
plt.figure(figsize=(8, 5))

sns.histplot(data=df, x="nr_employed", bins=20, kde=True)

plt.title("Distribution of Number of Employees")
plt.xlabel("Number of Employees")
plt.ylabel("Number of Customers")

plt.show()

# %% [markdown]
# ### Interpretation
#
# The distribution shows the range of values for the number of employees recorded during the marketing campaign.
# The values are concentrated around specific levels rather than being evenly distributed across the entire range.
# This variable provides information about the employment conditions during the campaign period.

# %% [markdown]
# ### Step 21: Univariate Analysis — Credit Default Status

# %% [markdown]
# ### Credit Default Status
#
# The `default` variable indicates whether a customer has a credit default.
# A count plot is used to compare the number of customers across the different credit default categories.

# %%
plt.figure(figsize=(8, 5))

sns.countplot(
    data=df,
    x="default",
    order=df["default"].value_counts().index
)

plt.title("Distribution of Customers by Credit Default Status")
plt.xlabel("Credit Default Status")
plt.ylabel("Number of Customers")

plt.show()

# %% [markdown]
# ### Interpretation
#
# The distribution shows the number of customers across different credit default categories.
# The categories are not evenly distributed, with one category representing the majority of observations.
# The `unknown` category represents customers for whom credit default information was unavailable and was retained during data cleaning.

# %% [markdown]
# ### Step 22: Bivariate Analysis — Job vs Term Deposit Subscription

# %% [markdown]
# ## Bivariate Analysis
#
# Bivariate analysis is used to study the relationship between two variables and identify patterns that may be associated with customer behavior.
#
# ### Job vs Term Deposit Subscription
#
# This analysis compares customer job categories with their term deposit subscription status.
# A count plot is used to compare the number of customers who subscribed and did not subscribe across different job categories.

# %%
plt.figure(figsize=(12, 6))

sns.countplot(
    data=df,
    x="job",
    hue="y",
    order=df["job"].value_counts().index
)

plt.title("Term Deposit Subscription by Job")
plt.xlabel("Job")
plt.ylabel("Number of Customers")
plt.xticks(rotation=45)

plt.legend(title="Subscription")

plt.show()

# %% [markdown]
# ### Interpretation
#
# The plot compares term deposit subscription outcomes across different job categories.
# For each job category, the number of customers who subscribed and did not subscribe can be compared.
# The plot helps identify whether subscription outcomes vary across different occupational groups.

# %% [markdown]
# ### Step 23: Bivariate Analysis — Education vs Term Deposit Subscription

# %% [markdown]
# ### Education vs Term Deposit Subscription
#
# This analysis compares customers' education levels with their term deposit subscription status.
# A grouped count plot is used to compare the number of subscribed and non-subscribed customers across education categories.

# %%
plt.figure(figsize=(12, 6))

sns.countplot(
    data=df,
    x="education",
    hue="y",
    order=df["education"].value_counts().index
)

plt.title("Term Deposit Subscription by Education")
plt.xlabel("Education")
plt.ylabel("Number of Customers")
plt.xticks(rotation=45)

plt.legend(title="Subscription")

plt.show()

# %% [markdown]
# ### Interpretation
#
# The plot compares term deposit subscription outcomes across different education categories.
# The number of subscribed and non-subscribed customers varies across education groups.
# This analysis helps identify differences in subscription patterns among customers with different educational backgrounds.

# %% [markdown]
# ### Step 24: Bivariate Analysis — Age vs Term Deposit Subscription

# %% [markdown]
# ### Age vs Term Deposit Subscription
#
# This analysis compares the age distribution of customers based on their term deposit subscription status.
# A box plot is used to compare the median, spread, and potential extreme values of age between subscribed and non-subscribed customers.

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(
    data=df,
    x="y",
    y="age"
)

plt.title("Age Distribution by Term Deposit Subscription")
plt.xlabel("Subscription")
plt.ylabel("Age")

plt.show()

# %% [markdown]
# ### Interpretation
#
# The box plot compares the age distribution between customers who subscribed and those who did not subscribe to the term deposit.
# The median age and overall spread can be compared between the two subscription groups.
# The plot also shows potential extreme age values within each group.

# %% [markdown]
# ### Step 25: Bivariate Analysis — Marital Status vs Term Deposit Subscription

# %% [markdown]
# ### Marital Status vs Term Deposit Subscription
#
# This analysis compares customers' marital status with their term deposit subscription status.
# A grouped count plot is used to compare subscribed and non-subscribed customers across different marital status categories.

# %%
plt.figure(figsize=(9, 5))

sns.countplot(
    data=df,
    x="marital",
    hue="y",
    order=df["marital"].value_counts().index
)

plt.title("Term Deposit Subscription by Marital Status")
plt.xlabel("Marital Status")
plt.ylabel("Number of Customers")

plt.legend(title="Subscription")

plt.show()

# %% [markdown]
# ### Interpretation
#
# The plot compares term deposit subscription outcomes across different marital status categories.
# The number of subscribed and non-subscribed customers varies across the marital status groups.
# This analysis helps identify differences in subscription patterns among customers with different marital statuses.

# %% [markdown]
# ### Step 26: Bivariate Analysis — Housing Loan vs Term Deposit Subscription

# %% [markdown]
# ### Housing Loan vs Term Deposit Subscription
#
# This analysis compares customers' housing loan status with their term deposit subscription status.
# A grouped count plot is used to compare subscribed and non-subscribed customers across housing loan categories.

# %%
plt.figure(figsize=(8, 5))

sns.countplot(
    data=df,
    x="housing",
    hue="y",
    order=df["housing"].value_counts().index
)

plt.title("Term Deposit Subscription by Housing Loan Status")
plt.xlabel("Housing Loan")
plt.ylabel("Number of Customers")

plt.legend(title="Subscription")

plt.show()

# %% [markdown]
# ### Interpretation
#
# The plot compares term deposit subscription outcomes between customers with different housing loan statuses.
# The number of subscribed and non-subscribed customers varies across the housing loan categories.
# This analysis helps examine whether subscription patterns differ according to housing loan status.

# %% [markdown]
# ### Step 27: Bivariate Analysis — Personal Loan vs Term Deposit Subscription

# %%
plt.figure(figsize=(8, 5))

sns.countplot(
    data=df,
    x="loan",
    hue="y",
    order=df["loan"].value_counts().index
)

plt.title("Term Deposit Subscription by Personal Loan Status")
plt.xlabel("Personal Loan")
plt.ylabel("Number of Customers")

plt.legend(title="Subscription")

plt.show()

# %% [markdown]
# ### Interpretation
#
# The plot compares term deposit subscription outcomes across customers with different personal loan statuses.
#
# The number of subscribed and non-subscribed customers varies across the personal loan categories.
#
# This analysis helps examine whether subscription patterns differ according to personal loan status.

# %% [markdown]
# ### Step 28: Bivariate Analysis — Contact Type vs Term Deposit Subscription

# %%
plt.figure(figsize=(8, 5))

sns.countplot(
    data=df,
    x="contact",
    hue="y",
    order=df["contact"].value_counts().index
)

plt.title("Term Deposit Subscription by Contact Type")
plt.xlabel("Contact Type")
plt.ylabel("Number of Customers")

plt.legend(title="Subscription")

plt.show()

# %% [markdown]
# ### Interpretation
#
# The plot compares term deposit subscription outcomes across different contact types.
#
# The number of subscribed and non-subscribed customers varies between the communication channels.
#
# This analysis helps examine whether customer subscription patterns differ depending on the contact method used by the bank.

# %% [markdown]
# ### Step 29: Bivariate Analysis — Previous Campaign Outcome vs Term Deposit Subscription

# %%
plt.figure(figsize=(9, 5))

sns.countplot(
    data=df,
    x="poutcome",
    hue="y",
    order=df["poutcome"].value_counts().index
)

plt.title("Term Deposit Subscription by Previous Campaign Outcome")
plt.xlabel("Previous Campaign Outcome")
plt.ylabel("Number of Customers")

plt.legend(title="Subscription")

plt.show()

# %% [markdown]
# ### Interpretation
#
# The plot compares current term deposit subscription outcomes across different previous campaign outcomes.
#
# Customers with different previous campaign outcomes show different patterns in their current subscription status.
#
# This analysis helps understand whether the result of a customer's previous campaign interaction is associated with their current term deposit subscription.

# %% [markdown]
# ### Step 30: Bivariate Analysis — Call Duration vs Term Deposit Subscription

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(
    data=df,
    x="y",
    y="duration"
)

plt.title("Call Duration by Term Deposit Subscription")
plt.xlabel("Term Deposit Subscription")
plt.ylabel("Call Duration (seconds)")

plt.show()

# %% [markdown]
# ### Interpretation
#
# The box plot compares the distribution of call duration for customers who subscribed (yes) and those who did not subscribe (no).
#
# It helps identify differences in the typical call duration, spread, and potential extreme values between the two groups.
#
# This analysis helps understand whether call duration is associated with customers' term deposit subscription outcomes.

# %% [markdown]
# ### Step 31: Bivariate Analysis — Campaign Contacts vs Term Deposit Subscription

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(
    data=df,
    x="y",
    y="campaign"
)

plt.title("Number of Campaign Contacts by Term Deposit Subscription")
plt.xlabel("Term Deposit Subscription")
plt.ylabel("Number of Campaign Contacts")

plt.show()

# %% [markdown]
# ### Interpretation
#
# The box plot compares the distribution of the number of campaign contacts for customers who subscribed (yes) and those who did not subscribe (no).
#
# It helps identify differences in the typical number of contacts, the spread of campaign contacts, and potential extreme values between the two groups.
#
# This analysis helps examine whether the number of contacts during the current campaign is associated with term deposit subscription outcomes.

# %% [markdown]
# ### Step 32: Multivariate Analysis — Age, Call Duration and Term Deposit Subscription

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(
    data=df,
    x="age",
    y="duration",
    hue="y",
    alpha=0.6
)

plt.title("Age and Call Duration by Term Deposit Subscription")
plt.xlabel("Age")
plt.ylabel("Call Duration (seconds)")

plt.legend(title="Subscription")

plt.show()

# %% [markdown]
# ### Interpretation
#
# The scatter plot shows the relationship between age and call duration, while the color grouping represents term deposit subscription status.
#
# The points show how call duration is distributed across different age groups and subscription outcomes.
#
# The plot also helps identify whether certain combinations of customer age and call duration appear more frequently among customers who subscribed.

# %% [markdown]
# ### Step 33: Multivariate Analysis — Job, Education and Term Deposit Subscription

# %%
g = sns.catplot(
    data=df,
    x="education",
    hue="y",
    col="job",
    col_wrap=3,
    kind="count",
    height=4,
    aspect=1.2
)

g.set_axis_labels("Education", "Number of Customers")
g.set_titles("Job: {col_name}")

g.fig.suptitle(
    "Term Deposit Subscription by Education and Job",
    y=1.02
)

plt.show()

# %% [markdown]
# ### Interpretation
#
# The plot compares term deposit subscription outcomes across different
# education levels and job categories.
#
# The separate panels represent different job categories, while the subscription
# status is shown using different colors.
#
# This analysis helps examine whether subscription patterns vary across both
# education and occupation.

# %% [markdown]
# ### Step 34: Multivariate Analysis — Contact Type, Campaign Contacts and Term Deposit Subscription

# %%
plt.figure(figsize=(10, 6))

sns.boxplot(
    data=df,
    x="contact",
    y="campaign",
    hue="y"
)

plt.title("Campaign Contacts by Contact Type and Term Deposit Subscription")
plt.xlabel("Contact Type")
plt.ylabel("Number of Campaign Contacts")

plt.legend(title="Subscription")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Interpretation
#
# The plot compares the number of campaign contacts across different communication types while also separating customers according to their term deposit subscription status.
#
# It helps identify differences in the distribution and spread of campaign contacts across contact types and subscription outcomes.
#
# This provides a broader view of how campaign contact frequency and communication method are related to customer subscription patterns.

# %% [markdown]
# ### Step 35: Multivariate Analysis — Previous Campaign Outcome, Previous Contacts and Term Deposit Subscription

# %%
plt.figure(figsize=(10, 6))

sns.boxplot(
    data=df,
    x="poutcome",
    y="previous",
    hue="y"
)

plt.title("Previous Contacts by Campaign Outcome and Term Deposit Subscription")
plt.xlabel("Previous Campaign Outcome")
plt.ylabel("Number of Previous Contacts")

plt.legend(title="Subscription")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Interpretation
#
# The plot compares the number of previous contacts across different previous campaign outcomes while separating customers according to their current term deposit subscription status.
#
# It helps identify differences in previous contact patterns among customers with different previous campaign outcomes.
#
# This analysis provides a broader view of how previous campaign interactions are associated with current subscription patterns.

# %% [markdown]
# ### Step 36: Multivariate Analysis — Education, Job and Term Deposit Subscription

# %%
education_job = pd.crosstab(
    df["education"],
    df["job"]
)

plt.figure(figsize=(12, 6))

sns.heatmap(
    education_job,
    annot=True,
    fmt="d",
    cmap="Blues"
)

plt.title("Customer Distribution by Education and Job")
plt.xlabel("Job")
plt.ylabel("Education")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Interpretation
#
# The heatmap shows the number of customers for each combination of education level and job type.
#
# Darker cells represent combinations with a higher number of customers, while lighter cells represent combinations with fewer customers.
#
# This analysis helps identify the major customer segments based on their education and employment characteristics.

# %% [markdown]
# ### Step 37: Multivariate Analysis — Age, Job and Term Deposit Subscription

# %%
plt.figure(figsize=(14, 6))

sns.boxplot(
    data=df,
    x="job",
    y="age",
    hue="y"
)

plt.title("Age Distribution by Job and Term Deposit Subscription")
plt.xlabel("Job")
plt.ylabel("Age")

plt.xticks(rotation=30)
plt.legend(title="Subscription")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Interpretation
#
# The plot compares the age distribution of customers across different job categories and subscription outcomes.
#
# It helps identify differences in the typical age and age spread of customers within each job category.
#
# By separating the results according to y, the analysis also helps examine whether the age patterns within different job groups vary between subscribed and non-subscribed customers.

# %% [markdown]
# ### Step 38: Multivariate Analysis — Marital Status, Education and Term Deposit Subscription

# %%
g = sns.catplot(
    data=df,
    x="education",
    hue="y",
    col="marital",
    col_wrap=2,
    kind="count",
    height=5,
    aspect=1.2
)

g.set_axis_labels("Education", "Number of Customers")
g.set_titles("Marital Status: {col_name}")

g.fig.suptitle(
    "Term Deposit Subscription by Education and Marital Status",
    y=1.02
)

plt.show()

# %% [markdown]
# ### Interpretation
#
# The plot shows how customers are distributed across different education levels and marital statuses.
#
# It helps identify which combinations of education and marital status are more common in the dataset.
#
# This provides a broader understanding of customer characteristics by examining multiple demographic variables together.

# %% [markdown]
# ### Step 39: Multivariate Analysis — Housing Loan, Personal Loan and Term Deposit Subscription

# %%
loan_comparison = pd.crosstab(
    [df["housing"], df["loan"]],
    df["y"]
)

loan_comparison.plot(
    kind="bar",
    figsize=(10, 6)
)

plt.title("Term Deposit Subscription by Housing and Personal Loan Status")
plt.xlabel("Housing Loan and Personal Loan")
plt.ylabel("Number of Customers")

plt.xticks(rotation=0)
plt.legend(title="Subscription")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Interpretation
#
# The plot compares term deposit subscription outcomes across different combinations of housing loan and personal loan status.
#
# It helps identify how customers with different loan combinations are distributed between subscribed and non-subscribed groups.
#
# This analysis provides a broader view of customer financial characteristics and their relationship with term deposit subscription.

# %% [markdown]
# ### Step 40: Multivariate Analysis — Contact Type, Previous Campaign Outcome and Term Deposit Subscription

# %%
g = sns.catplot(
    data=df,
    x="poutcome",
    hue="y",
    col="contact",
    kind="count",
    height=5,
    aspect=1
)

g.set_axis_labels("Previous Campaign Outcome", "Number of Customers")
g.set_titles("Contact Type: {col_name}")
g.fig.suptitle(
    "Term Deposit Subscription by Contact Type and Previous Campaign Outcome",
    y=1.05
)

plt.show()

# %% [markdown]
# ### Interpretation
#
# The plots compare term deposit subscription outcomes across different previous campaign outcomes and contact types.
#
# This helps examine whether subscription patterns vary depending on both the communication method and the result of the previous campaign.
#
# It provides a more detailed view of customer responses by combining three variables in one analysis.

# %% [markdown]
# ### Step 41: Multivariate Analysis — Employment Variation Rate, Euribor 3-Month Rate and Term Deposit Subscription

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(
    data=df,
    x="emp_var_rate",
    y="euribor3m",
    hue="y",
    alpha=0.6
)

plt.title("Employment Variation Rate and Euribor 3-Month Rate by Subscription")
plt.xlabel("Employment Variation Rate")
plt.ylabel("Euribor 3-Month Rate")

plt.legend(title="Subscription")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Interpretation
#
# The scatter plot shows the relationship between the employment variation rate and the 3-month Euribor rate, while the different subscription categories are shown separately.
#
# The distribution of points helps identify patterns and relationships between these economic indicators and customer subscription outcomes.
#
# This analysis provides a multivariate view by combining two numerical economic variables with the target variable y.

# %% [markdown]
# ### Step 42: Multivariate Analysis — Consumer Price Index, Consumer Confidence Index and Term Deposit Subscription

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(
    data=df,
    x="cons_price_idx",
    y="cons_conf_idx",
    hue="y",
    alpha=0.6
)

plt.title("Consumer Price Index and Consumer Confidence Index by Subscription")
plt.xlabel("Consumer Price Index")
plt.ylabel("Consumer Confidence Index")

plt.legend(title="Subscription")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Interpretation
#
# The scatter plot shows the relationship between the consumer price index and consumer confidence index, while the different colors represent term deposit subscription outcomes.
#
# The distribution of points helps identify how these two economic indicators vary across customers with different subscription outcomes.
#
# This analysis provides a multivariate view of the relationship between economic conditions and customer subscription patterns.

# %% [markdown]
# ## PART 8 - Pivot Table

# %% [markdown]
# ### Step 43: Pivot Table 1 — Term Deposit Subscription by Job

# %%
pivot_job = pd.pivot_table(
    df,
    index="job",
    columns="y",
    values="age",
    aggfunc="count",
    fill_value=0
)

pivot_job
# Out:
# y                no   yes
# job
# admin.         9068  1351
# blue-collar    8615   638
# entrepreneur   1332   124
# housemaid       954   106
# management     2596   328
# retired        1284   434
# self-employed  1272   149
# services       3644   323
# student         600   275
# technician     6009   730
# unemployed      870   144
# unknown         293    37

# %%
pivot_job["Total Customers"] = pivot_job.sum(axis=1)

pivot_job
# Out:
# y                no   yes  Total Customers
# job
# admin.         9068  1351            10419
# blue-collar    8615   638             9253
# entrepreneur   1332   124             1456
# housemaid       954   106             1060
# management     2596   328             2924
# retired        1284   434             1718
# self-employed  1272   149             1421
# services       3644   323             3967
# student         600   275              875
# technician     6009   730             6739
# unemployed      870   144             1014
# unknown         293    37              330

# %% [markdown]
# ### Step 44: Pivot Table 2 — Education vs Term Deposit Subscription

# %%
pivot_education = pd.pivot_table(
    df,
    index="education",
    columns="y",
    values="age",
    aggfunc="count",
    fill_value=0
)

pivot_education
# Out:
# y                       no   yes
# education
# basic.4y              3748   428
# basic.6y              2103   188
# basic.9y              5572   473
# high.school           8481  1031
# illiterate              14     4
# professional.course   4645   595
# university.degree    10495  1669
# unknown               1479   251

# %%
pivot_education["Total Customers"] = pivot_education.sum(axis=1)

pivot_education
# Out:
# y                       no   yes  Total Customers
# education
# basic.4y              3748   428             4176
# basic.6y              2103   188             2291
# basic.9y              5572   473             6045
# high.school           8481  1031             9512
# illiterate              14     4               18
# professional.course   4645   595             5240
# university.degree    10495  1669            12164
# unknown               1479   251             1730

# %% [markdown]
# ### Step 45: Pivot Table 3 — Marital Status vs Term Deposit Subscription

# %%
pivot_marital = pd.pivot_table(
    df,
    index="marital",
    columns="y",
    values="age",
    aggfunc="count",
    fill_value=0
)

pivot_marital
# Out:
# y            no   yes
# marital
# divorced   4135   476
# married   22390  2531
# single     9944  1620
# unknown      68    12

# %%
pivot_marital["Total Customers"] = pivot_marital.sum(axis=1)

pivot_marital
# Out:
# y            no   yes  Total Customers
# marital
# divorced   4135   476             4611
# married   22390  2531            24921
# single     9944  1620            11564
# unknown      68    12               80

# %% [markdown]
# ### Step 46: Pivot Table 4 — Housing Loan vs Term Deposit Subscription

# %%
pivot_housing = pd.pivot_table(
    df,
    index="housing",
    columns="y",
    values="age",
    aggfunc="count",
    fill_value=0
)

pivot_housing
# Out:
# y           no   yes
# housing
# no       16590  2025
# unknown    883   107
# yes      19064  2507

# %%
pivot_housing["Total Customers"] = pivot_housing.sum(axis=1)

pivot_housing
# Out:
# y           no   yes  Total Customers
# housing
# no       16590  2025            18615
# unknown    883   107              990
# yes      19064  2507            21571

# %% [markdown]
# ### Step 47: Pivot Table 5 — Personal Loan vs Term Deposit Subscriptionm

# %%
pivot_loan = pd.pivot_table(
    df,
    index="loan",
    columns="y",
    values="age",
    aggfunc="count",
    fill_value=0
)

pivot_loan
# Out:
# y           no   yes
# loan
# no       30089  3849
# unknown    883   107
# yes       5565   683

# %%
pivot_loan["Total Customers"] = pivot_loan.sum(axis=1)

pivot_loan
# Out:
# y           no   yes  Total Customers
# loan
# no       30089  3849            33938
# unknown    883   107              990
# yes       5565   683             6248

# %% [markdown]
# ### Step 48: Pivot Table 6 — Contact Type vs Term Deposit Subscription

# %%
pivot_contact = pd.pivot_table(
    df,
    index="contact",
    columns="y",
    values="age",
    aggfunc="count",
    fill_value=0
)

pivot_contact
# Out:
# y             no   yes
# contact
# cellular   22283  3852
# telephone  14254   787

# %%
pivot_contact["Total Customers"] = pivot_contact.sum(axis=1)

pivot_contact
# Out:
# y             no   yes  Total Customers
# contact
# cellular   22283  3852            26135
# telephone  14254   787            15041

# %% [markdown]
# ### Step 49: Pivot Table 7 — Previous Campaign Outcome vs Term Deposit Subscription

# %%
pivot_poutcome = pd.pivot_table(
    df,
    index="poutcome",
    columns="y",
    values="age",
    aggfunc="count",
    fill_value=0
)

pivot_poutcome
# Out:
# y               no   yes
# poutcome
# failure       3647   605
# nonexistent  32411  3140
# success        479   894

# %%
pivot_poutcome["Total Customers"] = pivot_poutcome.sum(axis=1)

pivot_poutcome
# Out:
# y               no   yes  Total Customers
# poutcome
# failure       3647   605             4252
# nonexistent  32411  3140            35551
# success        479   894             1373

# %% [markdown]
# ### Step 50: Pivot Table 8 — Campaign Contacts vs Term Deposit Subscription

# %%
df["campaign_group"] = pd.cut(
    df["campaign"],
    bins=[0, 1, 2, 3, 5, 10, float("inf")],
    labels=["1", "2", "3", "4-5", "6-10", "11+"]
)

pivot_campaign = pd.pivot_table(
    df,
    index="campaign_group",
    columns="y",
    values="age",
    aggfunc="count",
    fill_value=0
)

pivot_campaign
# Out:
# y                  no   yes
# campaign_group
# 1               15335  2299
# 2                9357  1211
# 3                4766   574
# 4-5              3880   369
# 6-10             2357   159
# 11+               842    27

# %%
pivot_campaign["Total Customers"] = pivot_campaign.sum(axis=1)

pivot_campaign
# Out:
# y                  no   yes  Total Customers
# campaign_group
# 1               15335  2299            17634
# 2                9357  1211            10568
# 3                4766   574             5340
# 4-5              3880   369             4249
# 6-10             2357   159             2516
# 11+               842    27              869

# %% [markdown]
# ### Step 51: Pivot Table 9 — Age Group vs Term Deposit Subscription

# %%
df["age_group"] = pd.cut(
    df["age"],
    bins=[0, 25, 35, 45, 55, 65, 100],
    labels=["18-25", "26-35", "36-45", "46-55", "56-65", "66+"]
)

pivot_age = pd.pivot_table(
    df,
    index="age_group",
    columns="y",
    values="age",
    aggfunc="count",
    fill_value=0
)

pivot_age
# Out:
# y             no   yes
# age_group
# 18-25       1316   349
# 26-35      13104  1740
# 36-45      11747  1092
# 46-55       7530   717
# 56-65       2512   451
# 66+          328   290

# %%
pivot_age["Total Customers"] = pivot_age.sum(axis=1)

pivot_age
# Out:
# y             no   yes  Total Customers
# age_group
# 18-25       1316   349             1665
# 26-35      13104  1740            14844
# 36-45      11747  1092            12839
# 46-55       7530   717             8247
# 56-65       2512   451             2963
# 66+          328   290              618

# %% [markdown]
# ### Step 52: Pivot Table 10 — Education + Job vs Term Deposit Subscription

# %%
pivot_education_job = pd.pivot_table(
    df,
    index="education",
    columns=["job", "y"],
    values="age",
    aggfunc="count",
    fill_value=0
)

pivot_education_job
# Out:
# job                 admin.      blue-collar      entrepreneur     housemaid  \
# y                       no  yes          no  yes           no yes        no
# education
# basic.4y                67   10        2195  123          130   7       423
# basic.6y               143    8        1318  107           62   9        72
# basic.9y               457   42        3383  240          198  12        91
# high.school           2947  382         784   94          218  16       160
# illiterate               1    0           8    0            1   1         1
# professional.course    314   49         412   41          126   9        48
# university.degree     4928  822          85    9          544  66       122
# unknown                211   38         430   24           53   4        37
#
# job                     management       ... services      student       \
# y                   yes         no  yes  ...       no  yes      no  yes
# education                                ...
# ...

# %% [markdown]
# ## PART 9 - Key Insights — Visual & Non-Visual Insights

# %% [markdown]
# ## Key Insights
#
# The exploratory data analysis and pivot tables provided several important
# observations about the Bank Marketing dataset.
#
# ### Customer Profile
# - The dataset contains customers from different age groups, occupations,
#   education levels, and marital-status categories.
# - Job, education, and marital status show noticeable differences in the
#   distribution of customers.
#
# ### Campaign Characteristics
# - The number of contacts made during the current campaign varies across
#   customers.
# - Call duration shows considerable variation and contains some extreme
#   observations.
# - Previous campaign outcomes provide additional information about customers'
#   earlier interactions with the bank.
#
# ### Contact and Loan Characteristics
# - Customers were contacted through different communication channels.
# - Housing loan and personal loan statuses vary across customers.
# - The pivot tables allow subscription patterns to be compared across these
#   customer characteristics.
#
# ### Economic Indicators
# - Variables such as employment variation rate, consumer price index,
#   consumer confidence index, Euribor 3-month rate, and number of employees
#   describe the economic conditions associated with the campaign data.
#
# ### Target Variable
# - The target variable `y` is imbalanced.
# - Most customers did not subscribe to the term deposit, while a smaller
#   proportion subscribed.
# - Therefore, subscription results should be interpreted with the original
#   class distribution in mind.
#
# ### Overall Observation
# The EDA shows that customer demographics, campaign-related variables,
# previous campaign interactions, contact methods, and economic indicators
# provide different perspectives for understanding term deposit subscription
# patterns.

# %% [markdown]
# ## PART 10 - Conclusion
#
# This project performed an Exploratory Data Analysis of the Bank Marketing
# dataset to understand customer characteristics, campaign interactions,
# previous campaign information, and term deposit subscription patterns.
#
# The dataset was cleaned and prepared by standardizing column names, checking
# for missing values, removing duplicate records, reviewing unknown categorical
# values, detecting potential outliers, and examining class imbalance.
#
# Univariate analysis was used to understand individual variables, while
# bivariate analysis examined relationships between customer and campaign
# variables and the target variable `y`. Multivariate analysis provided a
# broader view by examining multiple variables together.
#
# Pivot tables were also created to summarize subscription outcomes across
# different customer and campaign characteristics.
#
# Overall, the analysis provides a structured understanding of the Bank
# Marketing dataset and highlights the importance of customer characteristics,
# campaign interactions, previous campaign information, and economic
# indicators when studying term deposit subscription patterns.
